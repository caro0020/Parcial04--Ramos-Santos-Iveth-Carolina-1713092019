# %% [markdown]
# <a href="https://colab.research.google.com/github/caro0020/Parcial04--Ramos-Santos-Iveth-Carolina-1713092019/blob/main/ClaveE_Agrupacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("https://raw.githubusercontent.com/caro0020/Parcial04--Ramos-Santos-Iveth-Carolina-1713092019/refs/heads/main/clave_E_agrupacion.csv")

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
print("Duplicados:", df.duplicated().sum())
print(df.describe())
# Out:
# (246, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   registro_id       246 non-null    object
#  1   edad              246 non-null    int64
#  2   ingresos          246 non-null    int64
#  3   frecuencia_uso    246 non-null    float64
#  4   gasto_promedio    246 non-null    float64
#  5   satisfaccion      245 non-null    float64
#  6   reclamos          246 non-null    int64
#  7   antiguedad_meses  246 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 15.5+ KB
# None
# registro_id         0
# edad                0
# ingresos            0
# frecuencia_uso      0
# gasto_promedio      0
# satisfaccion        1
# reclamos            0
# antiguedad_meses    0
# dtype: int64
# Duplicados: 0
#              edad     ingresos  frecuencia_uso  gasto_promedio  satisfaccion  \
# ...
